# %% [markdown]
# **Pandas**

# %% [markdown]
# Data Manipulation : organize and structure raw data
#
# Data Analysis : find insights and trends from the data

# %% [markdown]
# Series : 1D dataframe, labelled array that can hold any datatype int, float etc
#
# DataFrame : 2D dataframe, labelled data structure

# %%
#importing library
import pandas as pd

# %% [markdown]
# **Read data**

# %%
df = pd.read_csv('employee_data.csv')

# %%
#printing first 5 rows
df.head()
# Out:
#    EmployeeID        Name Department JoiningDate  Salary  Bonus  \
# 0        1001  Employee_1  Marketing  2015-01-01   53483   8736
# 1        1002  Employee_2      Sales  2015-06-30   78555   2391
# 2        1003  Employee_3         IT  2015-12-27   47159  14706
# 3        1004  Employee_4      Sales  2016-06-24  110077  14666
# 4        1005  Employee_5      Sales  2016-12-21   65920   7892
#
#   PerformanceScore  LeavesTaken  RemoteWork
# 0        Excellent            4        True
# 1          Average            0       False
# 2          Average           18       False
# 3        Excellent            9        True
# 4             Poor           11        True

# %% [markdown]
# **Creating own DataFrame**

# %%
data = pd.DataFrame({
    'Name'  : ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace'],
    'Age'   : [25, 30, 35, 28, 40, 32, 27],
    'City'  : ['New York', 'San Francisco', 'Los Angeles',
               'Chicago', 'Houston', 'Boston', 'Seattle'],
    'Salary': [70000, 85000, 95000, 72000, 110000, 88000, 76000]
})

# %%
data.head()
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30  San Francisco   85000
# 2  Charlie   35    Los Angeles   95000
# 3    David   28        Chicago   72000
# 4     Emma   40        Houston  110000

# %% [markdown]
# **Save manipulated data**

# %%
data.to_excel('manipulated_data.xlsx', index=False)

# %% [markdown]
# **Data Exploration**
# 1. Understamd the data
# 2. Identify Problems
# 3. Plan next

# %% [markdown]
# info() - summarize the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        50 non-null     int64
#  1   Name              50 non-null     object
#  2   Department        50 non-null     object
#  3   JoiningDate       50 non-null     object
#  4   Salary            50 non-null     int64
#  5   Bonus             50 non-null     int64
#  6   PerformanceScore  50 non-null     object
#  7   LeavesTaken       50 non-null     int64
#  8   RemoteWork        50 non-null     bool
# dtypes: bool(1), int64(4), object(4)
# memory usage: 3.3+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   City    7 non-null      object
#  3   Salary  7 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes

# %% [markdown]
# describe() - statistical analysis

# %%
df.describe()
# Out:
#        EmployeeID         Salary         Bonus  LeavesTaken
# count    50.00000      50.000000     50.000000    50.000000
# mean   1025.50000   78344.500000   8514.460000    12.000000
# std      14.57738   27817.603904   3595.525548     8.131571
# min    1001.00000   31016.000000   2206.000000     0.000000
# 25%    1013.25000   53687.250000   5630.750000     4.000000
# 50%    1025.50000   78769.500000   8823.000000    12.500000
# 75%    1037.75000  100778.000000  10664.250000    19.000000
# max    1050.00000  119812.000000  14790.000000    23.000000

# %%
data.describe()
# Out:
#              Age         Salary
# count   7.000000       7.000000
# mean   31.000000   85142.857143
# std     5.163978   14194.230887
# min    25.000000   70000.000000
# 25%    27.500000   74000.000000
# 50%    30.000000   85000.000000
# 75%    33.500000   91500.000000
# max    40.000000  110000.000000

# %% [markdown]
# shape - no. of rows and columns

# %%
data.shape
# Out:
# (7, 4)

# %% [markdown]
# columns - names of columns

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='object')

# %% [markdown]
# **Selecting Columns**

# %% [markdown]
# Single Column

# %%
data['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4       Emma
# 5      Frank
# 6      Grace
# Name: Name, dtype: object

# %% [markdown]
# Multiple Column

# %%
data[['Name','Age','City']]
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago
# 4     Emma   40        Houston
# 5    Frank   32         Boston
# 6    Grace   27        Seattle

# %% [markdown]
# **Filtering Rows** -boolean indexing

# %%
data.head()
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30  San Francisco   85000
# 2  Charlie   35    Los Angeles   95000
# 3    David   28        Chicago   72000
# 4     Emma   40        Houston  110000

# %% [markdown]
# Single Condition

# %%
data[data['Salary'] > 72000]
# Out:
#       Name  Age           City  Salary
# 1      Bob   30  San Francisco   85000
# 2  Charlie   35    Los Angeles   95000
# 4     Emma   40        Houston  110000
# 5    Frank   32         Boston   88000
# 6    Grace   27        Seattle   76000

# %% [markdown]
# Multiple Condition

# %%
data[(data['Salary']>72000) & (data['Age']>=32)]
# Out:
#       Name  Age         City  Salary
# 2  Charlie   35  Los Angeles   95000
# 4     Emma   40      Houston  110000
# 5    Frank   32       Boston   88000

# %% [markdown]
# **Adding Column**

# %%
data.insert(4,'Bonus',0)  #(index, column name, data)

# %%
data.head()
# Out:
#       Name  Age           City  Salary  Bonus
# 0    Alice   25       New York   70000      0
# 1      Bob   30  San Francisco   85000      0
# 2  Charlie   35    Los Angeles   95000      0
# 3    David   28        Chicago   72000      0
# 4     Emma   40        Houston  110000      0

# %% [markdown]
# **Updating a value**

# %%
data.loc[1,'Name'] = 'Bobsie'

# %%
data.head()
# Out:
#       Name  Age           City  Salary  Bonus
# 0    Alice   25       New York   70000      0
# 1   Bobsie   30  San Francisco   85000      0
# 2  Charlie   35    Los Angeles   95000      0
# 3    David   28        Chicago   72000      0
# 4     Emma   40        Houston  110000      0

# %% [markdown]
# **Removing a column**

# %%
data.drop(columns = ['Bonus'])
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1   Bobsie   30  San Francisco   85000
# 2  Charlie   35    Los Angeles   95000
# 3    David   28        Chicago   72000
# 4     Emma   40        Houston  110000
# 5    Frank   32         Boston   88000
# 6    Grace   27        Seattle   76000

# %% [markdown]
# **Sorting** - arranging data

# %% [markdown]
# Single Column

# %%
data.sort_values(by='Salary', ascending=False, inplace=True)
data.head()
# Out:
#       Name  Age           City  Salary  Bonus
# 4     Emma   40        Houston  110000      0
# 2  Charlie   35    Los Angeles   95000      0
# 5    Frank   32         Boston   88000      0
# 1   Bobsie   30  San Francisco   85000      0
# 6    Grace   27        Seattle   76000      0

# %% [markdown]
# Multiple Column

# %%
data.sort_values(by=['Salary','Age'], ascending=[True,False], inplace=True)
data.head()
# Out:
#      Name  Age           City  Salary  Bonus
# 0   Alice   25       New York   70000      0
# 3   David   28        Chicago   72000      0
# 6   Grace   27        Seattle   76000      0
# 1  Bobsie   30  San Francisco   85000      0
# 5   Frank   32         Boston   88000      0

# %% [markdown]
# **Aggregation** - groupby()

# %%
data.groupby('Age')['Salary'].sum()
# Out:
# Age
# 25     70000
# 27     76000
# 28     72000
# 30     85000
# 32     88000
# 35     95000
# 40    110000
# Name: Salary, dtype: int64

# %% [markdown]
# **Merging Two DataFrames**

# %%
df_salary = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Salary": [70000, 85000, 95000, 72000]
})

df_info = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Department": ["HR", "IT", "Finance", "Marketing"]
})

# %%
df_merge = pd.merge(df_salary, df_info, on="Name")
print(df_merge)
# Out:
#       Name  Salary Department
# 0    Alice   70000         HR
# 1      Bob   85000         IT
# 2  Charlie   95000    Finance
# 3    David   72000  Marketing

# %% [markdown]
# **Concatenate two DataFrames**

# %%
df1 = pd.DataFrame({
    "Name": ["Alice", "Bob"],
    "Age": [25, 30],
    "City": ["New York", "San Francisco"]
})

df2 = pd.DataFrame({
    "Name": ["Charlie", "David"],
    "Age": [35, 28],
    "City": ["Los Angeles", "Chicago"]
})

# %%
df_concat = pd.concat([df1, df2], ignore_index=True)
print(df_concat)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %% [markdown]
# **Handling Missing Values**

# %% [markdown]
# isnull()/isna() - checks for missing values

# %%
import numpy as np

# %%
data = pd.DataFrame({
       "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace"],
    "Age": [25, np.nan, 35, 28, 40, np.nan, 27],
    "City": ["New York", "San Francisco", np.nan, "Chicago", "Houston", "Boston", "Seattle"],
    "Salary": [70000, 85000, np.nan, 72000, 110000, 88000, np.nan]
})

# %%
data.isnull().sum()
# Out:
# Name      0
# Age       2
# City      1
# Salary    2
# dtype: int64

# %% [markdown]
# Remove missing Values

# %%
data.dropna()
# Out:
#     Name   Age      City    Salary
# 0  Alice  25.0  New York   70000.0
# 3  David  28.0   Chicago   72000.0
# 4   Emma  40.0   Houston  110000.0

# %% [markdown]
# Fill the missing values

# %%
data.fillna(0, inplace=True)  #fill using 0 as a default

# %%
data.head()
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob   0.0  San Francisco   85000.0
# 2  Charlie  35.0              0       0.0
# 3    David  28.0        Chicago   72000.0
# 4     Emma  40.0        Houston  110000.0

# %%
data.fillna({"Salary": df["Salary"].median()},
          inplace=True)

# %%
data.head()
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob   0.0  San Francisco   85000.0
# 2  Charlie  35.0              0       0.0
# 3    David  28.0        Chicago   72000.0
# 4     Emma  40.0        Houston  110000.0
